# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Generating a Sierpinkski Triangle: (Tasks: 1-4)

# %%
# Defining vertices
t = np.linspace(0, (2 * np.pi), 4)
v = np.array([[np.cos(t[0]), np.cos(t[1]), np.cos(t[2])],
              [np.sin(t[0]), np.sin(t[1]), np.sin(t[2])]])

# Defining Starting point
T = np.array([[1/2, 0], [0, 1/2]])
x = np.array([0., 0.])

# Loop
n = 30000
for k in np.random.randint(3, size=n):
    x += np.matmul(T, (v[:, k] - x))
    plt.plot(x[0], x[1], 'b,')

plt.ylim(-1, 1)
plt.xlim(-0.8, 1.2)
plt.show()

# %% [markdown]
# Generating a Sierpinksi Triangle with a change of ratio: (Task: 5)

# %%
# Defining vertices
t = np.linspace(0, (2 * np.pi), 4)
v = np.array([[np.cos(t[0]), np.cos(t[1]), np.cos(t[2])],
              [np.sin(t[0]), np.sin(t[1]), np.sin(t[2])]])

# Defining Starting point
T = np.array([[1/3, 0], [0, 1/3]])
x = np.array([0., 0.])

# Loop
n = 30000
for k in np.random.randint(3, size=n):
    x += np.matmul(T, (v[:, k] - x))
    plt.plot(x[0], x[1], 'b,')

plt.ylim(-1, 1)
plt.xlim(-0.8, 1.2)
plt.show()

# %% [markdown]
# Generating Sierpinski Triangle with a change of rotation: (Task: 6)

# %%
# Defining vertices
t = np.linspace(0, (2 * np.pi), 4)
v = np.array([[np.cos(t[0]), np.cos(t[1]), np.cos(t[2])],
              [np.sin(t[0]), np.sin(t[1]), np.sin(t[2])]])

# Defining Starting point
## Adding rotation
theta = (math.pi)/18
T = 0.5 * (np.array([[math.cos(theta), -math.sin(theta)], [math.sin(theta), math.cos(theta)]]))
x = np.array([0., 0.])

# Loop
n = 30000
for k in np.random.randint(3, size=n):
    x += np.matmul(T, (v[:, k] - x))
    plt.plot(x[0], x[1], 'b,')

plt.ylim(-1, 1)
plt.xlim(-0.8, 1.2)
plt.show()

# %% [markdown]
# Generating a fractal from four vertices of a square: (Task: 7)

# %%
# Defining vertices
t = np.linspace(0, (2 * np.pi), 5)
v = np.array([[np.cos(t[0]), np.cos(t[1]), np.cos(t[2])],
              [np.sin(t[0]), np.sin(t[1]), np.sin(t[2])]])

# Defining Starting point
x = np.array([0., 0.])
T = np.array([[1/2, 0], [0, 1/2]])

# Loop
n = 30000
for k in np.random.randint(3, size=n):
    x += np.matmul(T, (v[:, k] - x))
    plt.plot(x[0], x[1], 'b,')

plt.show()

# %% [markdown]
# Generate a fractal from four vertices of a square with different rotation: (Task: 8)

# %%
# Defining vertices
t = np.linspace(0, (2 * np.pi), 5)
v = np.array([[np.cos(t[0]), np.cos(t[1]), np.cos(t[2])],
              [np.sin(t[0]), np.sin(t[1]), np.sin(t[2])]])

# Defining Starting point
x = np.array([0., 0.])
T = np.array([[1/3, 0], [0, 1/3]])

# Loop
n = 30000
for k in np.random.randint(3, size=n):
    x += np.matmul(T, (v[:, k] - x))
    plt.plot(x[0], x[1], 'b,')

plt.show()

# %% [markdown]
# Generate a fractal with square vertex preference: (Task: 9)

# %%
import cmath

# Defining vertices
t = np.linspace(0, (2 * np.pi), 5)
c = 0 + 1j
# imag = cmath.phase(complex(-1.0, 0.0))
v = np.array([cmath.exp((c.imag)*t[0]), cmath.exp((c.imag)*t[1]), cmath.exp((c.imag)*t[2])])

# Defining Starting point
x = np.array([0., 0.])
w = np.array([0., 0.])

T = np.array([[1/2, 0], [0, 1/2]])
print(v)
# Loop
n = 5000
k1 = 0
for k in np.random.randint(3, size=n):
    if(k >= k1):
        k += 1
        
    w = np.array([v.real], [v.imag])
    x += np.matmul(T, (w - x))
    k1=k
    
    plt.plot(x[0], x[1], 'b,')

plt.show()
# Out:
# [ 1.        +0.j  4.81047738+0.j 23.14069263+0.j]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/6r/599g2b5n2w50gqy1j7r_sbnc0000gn/T/ipykernel_69012/276932151.py in <module>
#      20         k += 1
#      21
# ---> 22     w = np.array([v.real], [v.imag])
#      23     x += np.matmul(T, (w - x))
#      24     k1=k
#
# TypeError: Field elements must be 2- or 3-tuples, got 'array([0., 0., 0.])'

# %% [markdown]
# Generating a Barnsley fern fractal: (Task: 11)

# %%
import random as rand

T1 = np.array(([0.85, 0.04], [-0.04, 0.85]))
T2 = np.array(([-0.15, 0.28], [0.26, 0.24]))
T3 = np.array(([0.2, -0.26], [0.23, 0.22]))
T4 = np.array(([0, 0], [0, 0.16]))
Q1 = np.array(([0], [1.64]))
Q2 = np.array(([-0.028], [1.05]))
Q3 = np.array(([0], [1.6]))
Q4 = np.array(([0], [0]))
P1 = 0.85
P2 = 0.07
P3 = 0.07
P4 = 0.01

n = 15000
x = np.array([0., 0.])

for k in np.random.randint(2, size=n):
    r = rand.random()
    if (r <= P1):
        x = np.matmul(T1, x) + Q1
    elif (r <= (P1+P2)):
        x = np.matmul(T2, x) + Q2
    elif (r <= (P1+P2+P3)):
        x = np.matmul(T3, x) + Q3
    else:
        x = np.matmul(T4, x) + Q4
    plt.plot(x[0, 0], x[1, 0], 'b,')

plt.ylim(0, 10)
plt.xlim(-6, 6)
plt.show()

# %% [markdown]
# Generating a fractal using the Sierpinki Triangle based on a regular hexagon: (Task: 12)

# %%
# Defining vertices
t = np.linspace(0, (2 * np.pi), 4)
v = np.array([[np.cos(t[0]), np.cos(t[1]), np.cos(t[2])],
              [np.sin(t[0]), np.sin(t[1]), np.sin(t[2])]])

# Defining Starting point
T = np.array([[1/4, 0], [0, 1/4]])
x = np.array([0., 0.])

# Loop
n = 30000
for k in np.random.randint(3, size=n):
    x += np.matmul(T, (v[:, k] - x))
    plt.plot(x[0], x[1], 'b,')

plt.ylim(-1, 1)
plt.xlim(-0.8, 1.2)
plt.show()

# %% [markdown]
# Create your own fractal (using matrix $T = [[2/5, 0], [0, 2/5]]$ ): (Task: 13)

# %%
# Defining vertices
t = np.linspace(0, (2 * np.pi), 4)
v = np.array([[np.cos(t[0]), np.cos(t[1]), np.cos(t[2])],
              [np.sin(t[0]), np.sin(t[1]), np.sin(t[2])]])

# Defining Starting point
T = np.array([[2/5, 0], [0, 2/5]])
x = np.array([0., 0.])

# Loop
n = 30000
for k in np.random.randint(3, size=n):
    x += np.matmul(T, (v[:, k] - x))
    plt.plot(x[0], x[1], 'b,')

plt.ylim(-1, 1)
plt.xlim(-0.8, 1.2)
plt.show()
